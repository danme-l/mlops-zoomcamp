# %% [markdown]
# # Trip Duration Model
# <a id='top'></a>
#
# [Experiment Tracking with MLFlow](#exp-tracking)
#
# Using the [NYC Taxis Data](https://www.nyc.gov/site/tlc/about/tlc-trip-record-data.page), Yellow taxi dataset for January and February 2022
#
# This is notebook is a copy of the same one I used for the intro section.

# %%
# standard data analysis
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# sklearn imports
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

from sklearn.metrics import mean_squared_error

# %%
# saving models
import pickle

# %%
# experiment tracking 
import mlflow

mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("nyc_taxi_exp")
# Out:
# <Experiment: artifact_location='/home/dan/mlops-zoomcamp/02-experiment-tracking/mlruns/1', creation_time=1684527324082, experiment_id='1', last_update_time=1684527324082, lifecycle_stage='active', name='nyc_taxi_exp', tags={}>

# %%
# create a processing function to reformat the input data
def process_taxis(filename):
    df = pd.read_parquet(f'../data/{filename}')

    # set duration feature
    df['duration'] = df['tpep_dropoff_datetime'] - df['tpep_pickup_datetime']
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

    # filter outliers
    df = df[(df.duration >= 1) & (df.duration <= 60)]

    # change cols to categorical
    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)

    df = df[['duration','PULocationID', 'DOLocationID']]
    
    return df

# %%
yellow_jan = process_taxis("yellow_tripdata_2022-01.parquet")

# %%
yellow_jan
# Out:
#           duration PULocationID DOLocationID
# 0        17.816667          142          236
# 1         8.400000          236           42
# 2         8.966667          166          166
# 3        10.033333          114           68
# 4        37.533333           68          163
# ...            ...          ...          ...
# 2463926   5.966667           90          170
# 2463927  10.650000          107           75
# 2463928  11.000000          113          246
# 2463929  12.050000          148          164
# 2463930  27.000000          186          181
#
# [2421440 rows x 3 columns]

# %%
# target vector
target = 'duration'

# %%
# turns the df into a giant list of dictionaries
train_dicts = yellow_jan.drop([target], axis=1).to_dict(orient='records')

# %%
# using the Dictionary Vectorizer from sklearn
dv = DictVectorizer()

# training feature matrix
X_train = dv.fit_transform(train_dicts)

# %%
# target vector
y_train = yellow_jan[target].values

# %%
# bring in the february data for validation
yellow_feb = process_taxis('yellow_tripdata_2022-02.parquet')

# %%
# turn categorical columns into list of dicts
val_dicts = yellow_feb.drop([target], axis=1).to_dict(orient='records')

# %%
# validation feature matrix
X_val = dv.transform(val_dicts)

# validation target matrix
y_val = yellow_feb[target].values

# %% [markdown]
# ## MLFlow & Experiment tracking
# <a id='exp-tracking'></a>
# [Top](#top)
#
# MLFlow is a python package for tracking experiments in a Machine Learning Project. It allows the developer to keep track of their results and the parameters and other facets of the model that produced those results.
#
# Sample run for MLFlow with a Lasso regression:

# %%
with mlflow.start_run():
    # data pathways
    mlflow.log_param("train_data_path", "data/yellow_tripdata_2022-01.parquet")
    mlflow.log_param("val_data_path", "data/yellow_tripdata_2022-02.parquet")

    alpha = 0.1
    mlflow.log_param("alpha", alpha)
    lr = Lasso()
    lr.fit(X_train, y_train)

    y_pred = lr.predict(X_val)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)

# %% [markdown]
# ### Using a more complicated model
# Optimizing an xgboost model with hyperopt

# %%
import xgboost as xgb

from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
def objective(params):
    """
    Trains and runs an xgboost model on the validation data
    Logs the results to MLFLow
    """
    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000, # maximum rounds of boosting
            evals=[(valid, "validation")], # validation set
            early_stopping_rounds=50 # stop training if there's 50 rounds without an improvement
        )
        y_pred = booster.predict(valid)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)
    
    return {'loss': rmse, 'status': STATUS_OK}

# %%
# range in which hyperopt should be exploring the hyperparameters
search_space = {
    # quniform returns real number, which we convert to int - tests from 4 to 100 
    'max_depth': scope.int(hp.quniform('max_depth',4,100,1)), 

    # these have logarithmic search spaces (log of of the return value is uniformally distributed)
    # var is constrained in that interval
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight',-1,3),
    'objective': 'reg:linear',
    'seed': 42
}

best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()
)
# Out:
# [14:18:19] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:13.59296
# [1]	validation-rmse:11.54505
# [2]	validation-rmse:10.06411
# [3]	validation-rmse:8.69966
# [4]	validation-rmse:7.99097
# [5]	validation-rmse:7.20874
# [6]	validation-rmse:6.67176
# [7]	validation-rmse:6.42908
# [8]	validation-rmse:6.12969
# [9]	validation-rmse:6.01087
# [10]	validation-rmse:5.83981
# [11]	validation-rmse:5.77922
# [12]	validation-rmse:5.68904
# [13]	validation-rmse:5.65564
# [14]	validation-rmse:5.63110
# [15]	validation-rmse:5.57407
# [16]	validation-rmse:5.56068
# [17]	validation-rmse:5.53972
# [18]	validation-rmse:5.53172
# [19]	validation-rmse:5.52371
# [20]	validation-rmse:5.49826
# [21]	validation-rmse:5.49458
# [22]	validation-rmse:5.48996
# [23]	validation-rmse:5.48701
# [24]	validation-rmse:5.46825
# [25]	validation-rmse:5.46643
# [26]	validation-rmse:5.45770
# [27]	validation-rmse:5.45651
# [28]	validation-rmse:5.45564
# [29]	validation-rmse:5.45369
# [30]	validation-rmse:5.44671
# [31]	validation-rmse:5.44181
# [32]	validation-rmse:5.44086
# [33]	validation-rmse:5.44004
# [34]	validation-rmse:5.43456
# [35]	validation-rmse:5.43420
# [36]	validation-rmse:5.43247
# [37]	validation-rmse:5.43179
# [38]	validation-rmse:5.43095
# [39]	validation-rmse:5.43027
# [40]	validation-rmse:5.43000
# [41]	validation-rmse:5.42969
# [42]	validation-rmse:5.42657
# [43]	validation-rmse:5.42591
# [44]	validation-rmse:5.42552
# [45]	validation-rmse:5.42512
# [46]	validation-rmse:5.42472
# [47]	validation-rmse:5.42461
# [48]	validation-rmse:5.42435
# [49]	validation-rmse:5.42332
# [50]	validation-rmse:5.42308
# [51]	validation-rmse:5.42299
# [52]	validation-rmse:5.42289
# [53]	validation-rmse:5.42177
# [54]	validation-rmse:5.42171
# [55]	validation-rmse:5.42119
# [56]	validation-rmse:5.42104
# [57]	validation-rmse:5.42089
# [58]	validation-rmse:5.42066
# [59]	validation-rmse:5.42037
# [60]	validation-rmse:5.42031
# [61]	validation-rmse:5.42022
# [62]	validation-rmse:5.42019
# [63]	validation-rmse:5.42009
# [64]	validation-rmse:5.42007
# [65]	validation-rmse:5.41994
# [66]	validation-rmse:5.41991
# [67]	validation-rmse:5.41973
# [68]	validation-rmse:5.41959
#   0%|          | 0/50 [09:45<?, ?trial/s, best loss=?]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 16
#       1 # range in which hyperopt should be exploring the hyperparameters
#       2 search_space = {
#       3     # quniform returns real number, which we convert to int - tests from 4 to 100
#       4     'max_depth': scope.int(hp.quniform('max_depth',4,100,1)),
#    (...)
#      13     'seed': 42
#      14 }
# ---> 16 best_result = fmin(
#      17     fn=objective,
#      18     space=search_space,
#      19     algo=tpe.suggest,
#      20     max_evals=50,
#      21     trials=Trials()
#      22 )
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:540, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     537     fn = __objective_fmin_wrapper(fn)
#     539 if allow_trials_fmin and hasattr(trials, "fmin"):
# --> 540     return trials.fmin(
#     541         fn,
#     542         space,
#     543         algo=algo,
#     544         max_evals=max_evals,
#     545         timeout=timeout,
#     546         loss_threshold=loss_threshold,
#     547         max_queue_len=max_queue_len,
#     548         rstate=rstate,
#     549         pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     550         verbose=verbose,
#     551         catch_eval_exceptions=catch_eval_exceptions,
#     552         return_argmin=return_argmin,
#     553         show_progressbar=show_progressbar,
#     554         early_stop_fn=early_stop_fn,
#     555         trials_save_file=trials_save_file,
#     556     )
#     558 if trials is None:
#     559     if os.path.exists(trials_save_file):
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/base.py:671, in Trials.fmin(self, fn, space, algo, max_evals, timeout, loss_threshold, max_queue_len, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar, early_stop_fn, trials_save_file)
#     666 # -- Stop-gap implementation!
#     667 #    fmin should have been a Trials method in the first place
#     668 #    but for now it's still sitting in another file.
#     669 from .fmin import fmin
# --> 671 return fmin(
#     672     fn,
#     673     space,
#     674     algo=algo,
#     675     max_evals=max_evals,
#     676     timeout=timeout,
#     677     loss_threshold=loss_threshold,
#     678     trials=self,
#     679     rstate=rstate,
#     680     verbose=verbose,
#     681     max_queue_len=max_queue_len,
#     682     allow_trials_fmin=False,  # -- prevent recursion
#     683     pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     684     catch_eval_exceptions=catch_eval_exceptions,
#     685     return_argmin=return_argmin,
#     686     show_progressbar=show_progressbar,
#     687     early_stop_fn=early_stop_fn,
#     688     trials_save_file=trials_save_file,
#     689 )
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:586, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     583 rval.catch_eval_exceptions = catch_eval_exceptions
#     585 # next line is where the fmin is actually executed
# --> 586 rval.exhaust()
#     588 if return_argmin:
#     589     if len(trials.trials) == 0:
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:364, in FMinIter.exhaust(self)
#     362 def exhaust(self):
#     363     n_done = len(self.trials)
# --> 364     self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     365     self.trials.refresh()
#     366     return self
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:300, in FMinIter.run(self, N, block_until_done)
#     297     time.sleep(self.poll_interval_secs)
#     298 else:
#     299     # -- loop over trials and do the jobs directly
# --> 300     self.serial_evaluate()
#     302 self.trials.refresh()
#     303 if self.trials_save_file != "":
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:178, in FMinIter.serial_evaluate(self, N)
#     176 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     177 try:
# --> 178     result = self.domain.evaluate(spec, ctrl)
#     179 except Exception as e:
#     180     logger.error("job exception: %s" % str(e))
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/base.py:892, in Domain.evaluate(self, config, ctrl, attach_attachments)
#     883 else:
#     884     # -- the "work" of evaluating `config` can be written
#     885     #    either into the pyll part (self.expr)
#     886     #    or the normal Python part (self.fn)
#     887     pyll_rval = pyll.rec_eval(
#     888         self.expr,
#     889         memo=memo,
#     890         print_node_on_error=self.rec_eval_print_node_on_error,
#     891     )
# --> 892     rval = self.fn(pyll_rval)
#     894 if isinstance(rval, (float, int, np.number)):
#     895     dict_rval = {"loss": float(rval), "status": STATUS_OK}
#
# Cell In[18], line 9, in objective(params)
#       7 mlflow.set_tag("model", "xgboost")
#       8 mlflow.log_params(params)
# ----> 9 booster = xgb.train(
#      10     params=params,
#      11     dtrain=train,
#      12     num_boost_round=1000, # maximum rounds of boosting
#      13     evals=[(valid, "validation")], # validation set
#      14     early_stopping_rounds=50 # stop training if there's 50 rounds without an improvement
#      15 )
#      16 y_pred = booster.predict(valid)
#      17 rmse = mean_squared_error(y_val, y_pred, squared=False)
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/training.py:185, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     183 if cb_container.before_iteration(bst, i, dtrain, evals):
#     184     break
# --> 185 bst.update(dtrain, i, obj)
#     186 if cb_container.after_iteration(bst, i, dtrain, evals):
#     187     break
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:1918, in Booster.update(self, dtrain, iteration, fobj)
#    1915 self._validate_dmatrix_features(dtrain)
#    1917 if fobj is None:
# -> 1918     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1919                                             ctypes.c_int(iteration),
#    1920                                             dtrain.handle))
#    1921 else:
#    1922     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %% [markdown]
# Currently not working with a GPU so I'm just going to steal the winning parameter results from Christian's video [MLOops Zoomcamp 2.3](https://www.youtube.com/watch?v=iaJz-T7VWec&list=PL3MmuxUbc_hIUISrluw_A7wDSmfOhErJK&index=13)

# %%
params = {
    'learning_rate': 0.20472169880371677,
    'max_depth': 17,
    'min_child_weight': 1.2402611720043835,
    'objective': 'reg:linear',
    'reg_alpha': 0.2567896734700793,
    'reg_lambda': 0.004264404814393109,
    'seed': 42
}

mlflow.xgboost.autolog()

booster = xgb.train(
        params=params,
        dtrain=train,
        num_boost_round=1000, # maximum rounds of boosting
        evals=[(valid, "validation")], # validation set
        early_stopping_rounds=50 # stop training if there's 50 rounds without an improvement
    )
# Out:
# 2023/05/21 14:59:05 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '16157ba0a7694057863848511b4f5f37', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# [14:59:05] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:14.13654
# [1]	validation-rmse:12.41407
# [2]	validation-rmse:11.13752
# [3]	validation-rmse:10.20585
# [4]	validation-rmse:9.52644
# [5]	validation-rmse:9.03517
# [6]	validation-rmse:8.61399
# [7]	validation-rmse:8.35407
# [8]	validation-rmse:8.16316
# [9]	validation-rmse:8.02544
# [10]	validation-rmse:7.86176
# [11]	validation-rmse:7.78026
# [12]	validation-rmse:7.70959
# [13]	validation-rmse:7.65227
# [14]	validation-rmse:7.61065
# [15]	validation-rmse:7.56120
# [16]	validation-rmse:7.52321
# [17]	validation-rmse:7.45013
# [18]	validation-rmse:7.42742
# [19]	validation-rmse:7.40429
# [20]	validation-rmse:7.38648
# [21]	validation-rmse:7.36524
# [22]	validation-rmse:7.34339
# [23]	validation-rmse:7.32905
# [24]	validation-rmse:7.31197
# [25]	validation-rmse:7.24365
# [26]	validation-rmse:7.23123
# [27]	validation-rmse:7.20749
# [28]	validation-rmse:7.19439
# [29]	validation-rmse:7.17239
# [30]	validation-rmse:7.16097
# [31]	validation-rmse:7.08732
# [32]	validation-rmse:7.03359
# [33]	validation-rmse:7.02734
# [34]	validation-rmse:7.01876
# [35]	validation-rmse:7.01325
# [36]	validation-rmse:7.00708
# [37]	validation-rmse:6.99749
# [38]	validation-rmse:6.98802
# [39]	validation-rmse:6.98126
# [40]	validation-rmse:6.96868
# [41]	validation-rmse:6.94852
# [42]	validation-rmse:6.94369
# [43]	validation-rmse:6.93841
# [44]	validation-rmse:6.93172
# [45]	validation-rmse:6.92661
# [46]	validation-rmse:6.85456
# [47]	validation-rmse:6.81742
# [48]	validation-rmse:6.81386
# [49]	validation-rmse:6.78776
# [50]	validation-rmse:6.78383
# [51]	validation-rmse:6.77633
# [52]	validation-rmse:6.77114
# [53]	validation-rmse:6.76273
# [54]	validation-rmse:6.75427
# [55]	validation-rmse:6.75150
# [56]	validation-rmse:6.74760
# [57]	validation-rmse:6.74144
# [58]	validation-rmse:6.73560
# [59]	validation-rmse:6.73195
# [60]	validation-rmse:6.70671
# [61]	validation-rmse:6.66506
# [62]	validation-rmse:6.66319
# [63]	validation-rmse:6.61921
# [64]	validation-rmse:6.57989
# [65]	validation-rmse:6.57582
# [66]	validation-rmse:6.57260
# [67]	validation-rmse:6.56688
# [68]	validation-rmse:6.56284
# [69]	validation-rmse:6.56095
# [70]	validation-rmse:6.55691
# [71]	validation-rmse:6.55218
# [72]	validation-rmse:6.54905
# [73]	validation-rmse:6.54262
# [74]	validation-rmse:6.53932
# [75]	validation-rmse:6.53724
# [76]	validation-rmse:6.53378
# [77]	validation-rmse:6.53184
# [78]	validation-rmse:6.49903
# [79]	validation-rmse:6.46585
# [80]	validation-rmse:6.43723
# [81]	validation-rmse:6.43015
# [82]	validation-rmse:6.42806
# [83]	validation-rmse:6.42578
# [84]	validation-rmse:6.42273
# [85]	validation-rmse:6.42063
# [86]	validation-rmse:6.40944
# [87]	validation-rmse:6.40510
# [88]	validation-rmse:6.40139
# [89]	validation-rmse:6.39841
# [90]	validation-rmse:6.39639
# [91]	validation-rmse:6.39491
# [92]	validation-rmse:6.39099
# [93]	validation-rmse:6.38975
# [94]	validation-rmse:6.36598
# [95]	validation-rmse:6.34726
# [96]	validation-rmse:6.32014
# [97]	validation-rmse:6.31919
# [98]	validation-rmse:6.31827
# [99]	validation-rmse:6.31680
# [100]	validation-rmse:6.29287
# [101]	validation-rmse:6.28000
# [102]	validation-rmse:6.26625
# [103]	validation-rmse:6.26511
# [104]	validation-rmse:6.26220
# [105]	validation-rmse:6.26051
# [106]	validation-rmse:6.25904
# [107]	validation-rmse:6.25571
# [108]	validation-rmse:6.25470
# [109]	validation-rmse:6.23832
# [110]	validation-rmse:6.23660
# [111]	validation-rmse:6.23536
# [112]	validation-rmse:6.23454
# [113]	validation-rmse:6.23179
# [114]	validation-rmse:6.23045
# [115]	validation-rmse:6.22986
# [116]	validation-rmse:6.22780
# [117]	validation-rmse:6.21004
# [118]	validation-rmse:6.20568
# [119]	validation-rmse:6.20421
# [120]	validation-rmse:6.19982
# [121]	validation-rmse:6.19911
# [122]	validation-rmse:6.19842
# [123]	validation-rmse:6.19588
# [124]	validation-rmse:6.19276
# [125]	validation-rmse:6.19180
# [126]	validation-rmse:6.19042
# [127]	validation-rmse:6.17379
# [128]	validation-rmse:6.15058
# [129]	validation-rmse:6.14256
# [130]	validation-rmse:6.13266
# [131]	validation-rmse:6.13107
# [132]	validation-rmse:6.13020
# [133]	validation-rmse:6.12934
# [134]	validation-rmse:6.12865
# [135]	validation-rmse:6.12812
# [136]	validation-rmse:6.12562
# [137]	validation-rmse:6.12448
# [138]	validation-rmse:6.12264
# [139]	validation-rmse:6.12147
# [140]	validation-rmse:6.12049
# [141]	validation-rmse:6.11925
# [142]	validation-rmse:6.10357
# [143]	validation-rmse:6.08531
# [144]	validation-rmse:6.06518
# [145]	validation-rmse:6.05150
# [146]	validation-rmse:6.05033
# [147]	validation-rmse:6.04953
# [148]	validation-rmse:6.04824
# [149]	validation-rmse:6.04788
# [150]	validation-rmse:6.04185
# [151]	validation-rmse:6.03141
# [152]	validation-rmse:6.03055
# [153]	validation-rmse:6.02869
# [154]	validation-rmse:6.02623
# [155]	validation-rmse:6.02016
# [156]	validation-rmse:6.01960
# [157]	validation-rmse:6.01911
# [158]	validation-rmse:6.01858
# [159]	validation-rmse:6.01808
# [160]	validation-rmse:6.00744
# [161]	validation-rmse:6.00010
# [162]	validation-rmse:5.98320
# [163]	validation-rmse:5.98224
# [164]	validation-rmse:5.98109
# [165]	validation-rmse:5.97047
# [166]	validation-rmse:5.97028
# [167]	validation-rmse:5.96989
# [168]	validation-rmse:5.96922
# [169]	validation-rmse:5.96876
# [170]	validation-rmse:5.96836
# [171]	validation-rmse:5.95366
# [172]	validation-rmse:5.94357
# [173]	validation-rmse:5.92855
# [174]	validation-rmse:5.92681
# [175]	validation-rmse:5.92626
# [176]	validation-rmse:5.92423
# [177]	validation-rmse:5.92358
# [178]	validation-rmse:5.91744
# [179]	validation-rmse:5.90469
# [180]	validation-rmse:5.89713
# [181]	validation-rmse:5.89693
# [182]	validation-rmse:5.89613
# [183]	validation-rmse:5.89572
# [184]	validation-rmse:5.89519
# [185]	validation-rmse:5.89479
# [186]	validation-rmse:5.89366
# [187]	validation-rmse:5.89333
# [188]	validation-rmse:5.89155
# [189]	validation-rmse:5.88960
# [190]	validation-rmse:5.88903
# [191]	validation-rmse:5.88821
# [192]	validation-rmse:5.88803
# [193]	validation-rmse:5.88684
# [194]	validation-rmse:5.88661
# [195]	validation-rmse:5.88571
# [196]	validation-rmse:5.88020
# [197]	validation-rmse:5.87947
# [198]	validation-rmse:5.87916
# [199]	validation-rmse:5.87887
# [200]	validation-rmse:5.87664
# [201]	validation-rmse:5.86297
# [202]	validation-rmse:5.85299
# [203]	validation-rmse:5.84739
# [204]	validation-rmse:5.84137
# [205]	validation-rmse:5.83234
# [206]	validation-rmse:5.82198
# [207]	validation-rmse:5.81452
# [208]	validation-rmse:5.81417
# [209]	validation-rmse:5.81031
# [210]	validation-rmse:5.80946
# [211]	validation-rmse:5.80918
# [212]	validation-rmse:5.80829
# [213]	validation-rmse:5.80744
# [214]	validation-rmse:5.80726
# [215]	validation-rmse:5.80699
# [216]	validation-rmse:5.80401
# [217]	validation-rmse:5.80380
# [218]	validation-rmse:5.80364
# [219]	validation-rmse:5.79926
# [220]	validation-rmse:5.79888
# [221]	validation-rmse:5.79869
# [222]	validation-rmse:5.79854
# [223]	validation-rmse:5.79625
# [224]	validation-rmse:5.79203
# [225]	validation-rmse:5.78945
# [226]	validation-rmse:5.78709
# [227]	validation-rmse:5.78549
# [228]	validation-rmse:5.78449
# [229]	validation-rmse:5.78415
# [230]	validation-rmse:5.78261
# [231]	validation-rmse:5.78235
# [232]	validation-rmse:5.78065
# [233]	validation-rmse:5.78002
# [234]	validation-rmse:5.77902
# [235]	validation-rmse:5.77846
# [236]	validation-rmse:5.76813
# [237]	validation-rmse:5.75850
# [238]	validation-rmse:5.75075
# [239]	validation-rmse:5.74427
# [240]	validation-rmse:5.74281
# [241]	validation-rmse:5.74166
# [242]	validation-rmse:5.74155
# [243]	validation-rmse:5.74111
# [244]	validation-rmse:5.73815
# [245]	validation-rmse:5.73799
# [246]	validation-rmse:5.73698
# [247]	validation-rmse:5.73659
# [248]	validation-rmse:5.73607
# [249]	validation-rmse:5.73576
# [250]	validation-rmse:5.73562
# [251]	validation-rmse:5.73509
# [252]	validation-rmse:5.73408
# [253]	validation-rmse:5.73319
# [254]	validation-rmse:5.73281
# [255]	validation-rmse:5.72611
# [256]	validation-rmse:5.72006
# [257]	validation-rmse:5.71808
# [258]	validation-rmse:5.71184
# [259]	validation-rmse:5.70776
# [260]	validation-rmse:5.70716
# [261]	validation-rmse:5.70595
# [262]	validation-rmse:5.70173
# [263]	validation-rmse:5.70014
# [264]	validation-rmse:5.69973
# [265]	validation-rmse:5.69968
# [266]	validation-rmse:5.69896
# [267]	validation-rmse:5.69857
# [268]	validation-rmse:5.69316
# [269]	validation-rmse:5.68896
# [270]	validation-rmse:5.68737
# [271]	validation-rmse:5.68600
# [272]	validation-rmse:5.68514
# [273]	validation-rmse:5.68389
# [274]	validation-rmse:5.68298
# [275]	validation-rmse:5.68207
# [276]	validation-rmse:5.68111
# [277]	validation-rmse:5.67663
# [278]	validation-rmse:5.67374
# [279]	validation-rmse:5.66778
# [280]	validation-rmse:5.66731
# [281]	validation-rmse:5.66708
# [282]	validation-rmse:5.66501
# [283]	validation-rmse:5.66303
# [284]	validation-rmse:5.66187
# [285]	validation-rmse:5.66181
# [286]	validation-rmse:5.66174
# [287]	validation-rmse:5.66164
# [288]	validation-rmse:5.66094
# [289]	validation-rmse:5.66088
# [290]	validation-rmse:5.66000
# [291]	validation-rmse:5.65503
# [292]	validation-rmse:5.65089
# [293]	validation-rmse:5.64697
# [294]	validation-rmse:5.64594
# [295]	validation-rmse:5.64266
# [296]	validation-rmse:5.63918
# [297]	validation-rmse:5.63754
# [298]	validation-rmse:5.63333
# [299]	validation-rmse:5.63253
# [300]	validation-rmse:5.62926
# [301]	validation-rmse:5.62815
# [302]	validation-rmse:5.62789
# [303]	validation-rmse:5.62763
# [304]	validation-rmse:5.62596
# [305]	validation-rmse:5.62537
# [306]	validation-rmse:5.62527
# [307]	validation-rmse:5.62525
# [308]	validation-rmse:5.62505
# [309]	validation-rmse:5.62496
# [310]	validation-rmse:5.62493
# [311]	validation-rmse:5.62457
# [312]	validation-rmse:5.62396
# [313]	validation-rmse:5.62357
# [314]	validation-rmse:5.62294
# [315]	validation-rmse:5.62201
# [316]	validation-rmse:5.61926
# [317]	validation-rmse:5.61729
# [318]	validation-rmse:5.61579
# [319]	validation-rmse:5.61500
# [320]	validation-rmse:5.61441
# [321]	validation-rmse:5.61412
# [322]	validation-rmse:5.61386
# [323]	validation-rmse:5.61232
# [324]	validation-rmse:5.61064
# [325]	validation-rmse:5.60983
# [326]	validation-rmse:5.60629
# [327]	validation-rmse:5.60567
# [328]	validation-rmse:5.60401
# [329]	validation-rmse:5.60387
# [330]	validation-rmse:5.60359
# [331]	validation-rmse:5.60347
# [332]	validation-rmse:5.60224
# [333]	validation-rmse:5.60183
# [334]	validation-rmse:5.59969
# [335]	validation-rmse:5.59708
# [336]	validation-rmse:5.59517
# [337]	validation-rmse:5.59362
# [338]	validation-rmse:5.59282
# [339]	validation-rmse:5.59159
# [340]	validation-rmse:5.59141
# [341]	validation-rmse:5.58871
# [342]	validation-rmse:5.58739
# [343]	validation-rmse:5.58477
# [344]	validation-rmse:5.58140
# [345]	validation-rmse:5.57891
# [346]	validation-rmse:5.57856
# [347]	validation-rmse:5.57716
# [348]	validation-rmse:5.57656
# [349]	validation-rmse:5.57654
# [350]	validation-rmse:5.57603
# [351]	validation-rmse:5.57582
# [352]	validation-rmse:5.57543
# [353]	validation-rmse:5.57520
# [354]	validation-rmse:5.57494
# [355]	validation-rmse:5.57399
# [356]	validation-rmse:5.57385
# [357]	validation-rmse:5.57381
# [358]	validation-rmse:5.57377
# [359]	validation-rmse:5.57367
# [360]	validation-rmse:5.57345
# [361]	validation-rmse:5.57308
# [362]	validation-rmse:5.57244
# [363]	validation-rmse:5.57214
# [364]	validation-rmse:5.57191
# [365]	validation-rmse:5.57183
# [366]	validation-rmse:5.57168
# [367]	validation-rmse:5.57151
# [368]	validation-rmse:5.57119
# [369]	validation-rmse:5.57115
# [370]	validation-rmse:5.57029
# [371]	validation-rmse:5.56860
# [372]	validation-rmse:5.56732
# [373]	validation-rmse:5.56621
# [374]	validation-rmse:5.56529
# [375]	validation-rmse:5.56465
# [376]	validation-rmse:5.56451
# [377]	validation-rmse:5.56419
# [378]	validation-rmse:5.56395
# [379]	validation-rmse:5.56371
# [380]	validation-rmse:5.56368
# [381]	validation-rmse:5.56361
# [382]	validation-rmse:5.56331
# [383]	validation-rmse:5.56187
# [384]	validation-rmse:5.56051
# [385]	validation-rmse:5.56035
# [386]	validation-rmse:5.56030
# [387]	validation-rmse:5.55970
# [388]	validation-rmse:5.55817
# [389]	validation-rmse:5.55679
# [390]	validation-rmse:5.55618
# [391]	validation-rmse:5.55555
# [392]	validation-rmse:5.55446
# [393]	validation-rmse:5.55397
# [394]	validation-rmse:5.55338
# [395]	validation-rmse:5.55266
# [396]	validation-rmse:5.55265
# [397]	validation-rmse:5.55258
# [398]	validation-rmse:5.55253
# [399]	validation-rmse:5.55238
# [400]	validation-rmse:5.55227
# [401]	validation-rmse:5.55211
# [402]	validation-rmse:5.55189
# [403]	validation-rmse:5.55184
# [404]	validation-rmse:5.55180
# [405]	validation-rmse:5.55159
# [406]	validation-rmse:5.55091
# [407]	validation-rmse:5.55039
# [408]	validation-rmse:5.55021
# [409]	validation-rmse:5.54996
# [410]	validation-rmse:5.54983
# [411]	validation-rmse:5.54966
# [412]	validation-rmse:5.54952
# [413]	validation-rmse:5.54949
# [414]	validation-rmse:5.54936
# [415]	validation-rmse:5.54826
# [416]	validation-rmse:5.54746
# [417]	validation-rmse:5.54708
# [418]	validation-rmse:5.54567
# [419]	validation-rmse:5.54409
# [420]	validation-rmse:5.54328
# [421]	validation-rmse:5.54245
# [422]	validation-rmse:5.54197
# [423]	validation-rmse:5.54112
# [424]	validation-rmse:5.54084
# [425]	validation-rmse:5.54064
# [426]	validation-rmse:5.54034
# [427]	validation-rmse:5.53977
# [428]	validation-rmse:5.53809
# [429]	validation-rmse:5.53718
# [430]	validation-rmse:5.53687
# [431]	validation-rmse:5.53590
# [432]	validation-rmse:5.53494
# [433]	validation-rmse:5.53385
# [434]	validation-rmse:5.53359
# [435]	validation-rmse:5.53353
# [436]	validation-rmse:5.53312
# [437]	validation-rmse:5.53295
# [438]	validation-rmse:5.53256
# [439]	validation-rmse:5.53193
# [440]	validation-rmse:5.53096
# [441]	validation-rmse:5.53073
# [442]	validation-rmse:5.53060
# [443]	validation-rmse:5.53047
# [444]	validation-rmse:5.53031
# [445]	validation-rmse:5.53011
# [446]	validation-rmse:5.53008
# [447]	validation-rmse:5.52989
# [448]	validation-rmse:5.52974
# [449]	validation-rmse:5.52928
# [450]	validation-rmse:5.52834
# [451]	validation-rmse:5.52757
# [452]	validation-rmse:5.52712
# [453]	validation-rmse:5.52651
# [454]	validation-rmse:5.52602
# [455]	validation-rmse:5.52577
# [456]	validation-rmse:5.52550
# [457]	validation-rmse:5.52454
# [458]	validation-rmse:5.52375
# [459]	validation-rmse:5.52348
# [460]	validation-rmse:5.52238
# [461]	validation-rmse:5.52222
# [462]	validation-rmse:5.52186
# [463]	validation-rmse:5.52161
# [464]	validation-rmse:5.52130
# [465]	validation-rmse:5.52071
# [466]	validation-rmse:5.52057
# [467]	validation-rmse:5.52043
# [468]	validation-rmse:5.52040
# [469]	validation-rmse:5.52023
# [470]	validation-rmse:5.52004
# [471]	validation-rmse:5.51993
# [472]	validation-rmse:5.51976
# [473]	validation-rmse:5.51974
# [474]	validation-rmse:5.51971
# [475]	validation-rmse:5.51957
# [476]	validation-rmse:5.51955
# [477]	validation-rmse:5.51944
# [478]	validation-rmse:5.51942
# [479]	validation-rmse:5.51838
# [480]	validation-rmse:5.51676
# [481]	validation-rmse:5.51577
# [482]	validation-rmse:5.51426
# [483]	validation-rmse:5.51355
# [484]	validation-rmse:5.51322
# [485]	validation-rmse:5.51294
# [486]	validation-rmse:5.51199
# [487]	validation-rmse:5.51162
# [488]	validation-rmse:5.51140
# [489]	validation-rmse:5.51071
# [490]	validation-rmse:5.51040
# [491]	validation-rmse:5.50982
# [492]	validation-rmse:5.50941
# [493]	validation-rmse:5.50928
# [494]	validation-rmse:5.50859
# [495]	validation-rmse:5.50828
# [496]	validation-rmse:5.50812
# [497]	validation-rmse:5.50759
# [498]	validation-rmse:5.50721
# [499]	validation-rmse:5.50686
# [500]	validation-rmse:5.50666
# [501]	validation-rmse:5.50649
# [502]	validation-rmse:5.50648
# [503]	validation-rmse:5.50630
# [504]	validation-rmse:5.50626
# [505]	validation-rmse:5.50618
# [506]	validation-rmse:5.50602
# [507]	validation-rmse:5.50586
# [508]	validation-rmse:5.50585
# [509]	validation-rmse:5.50575
# [510]	validation-rmse:5.50533
# [511]	validation-rmse:5.50531
# [512]	validation-rmse:5.50496
# [513]	validation-rmse:5.50495
# [514]	validation-rmse:5.50487
# [515]	validation-rmse:5.50463
# [516]	validation-rmse:5.50464
# [517]	validation-rmse:5.50465
# [518]	validation-rmse:5.50462
# [519]	validation-rmse:5.50447
# [520]	validation-rmse:5.50406
# [521]	validation-rmse:5.50396
# [522]	validation-rmse:5.50335
# [523]	validation-rmse:5.50279
# [524]	validation-rmse:5.50221
# [525]	validation-rmse:5.50197
# [526]	validation-rmse:5.50178
# [527]	validation-rmse:5.50172
# [528]	validation-rmse:5.50163
# [529]	validation-rmse:5.50139
# [530]	validation-rmse:5.50133
# [531]	validation-rmse:5.50127
# [532]	validation-rmse:5.50110
# [533]	validation-rmse:5.50104
# [534]	validation-rmse:5.50058
# [535]	validation-rmse:5.50044
# [536]	validation-rmse:5.49990
# [537]	validation-rmse:5.49955
# [538]	validation-rmse:5.49909
# [539]	validation-rmse:5.49905
# [540]	validation-rmse:5.49896
# [541]	validation-rmse:5.49863
# [542]	validation-rmse:5.49857
# [543]	validation-rmse:5.49840
# [544]	validation-rmse:5.49833
# [545]	validation-rmse:5.49822
# [546]	validation-rmse:5.49815
# [547]	validation-rmse:5.49781
# [548]	validation-rmse:5.49734
# [549]	validation-rmse:5.49672
# [550]	validation-rmse:5.49664
# [551]	validation-rmse:5.49624
# [552]	validation-rmse:5.49609
# [553]	validation-rmse:5.49601
# [554]	validation-rmse:5.49586
# [555]	validation-rmse:5.49555
# [556]	validation-rmse:5.49509
# [557]	validation-rmse:5.49494
# [558]	validation-rmse:5.49477
# [559]	validation-rmse:5.49474
# [560]	validation-rmse:5.49468
# [561]	validation-rmse:5.49465
# [562]	validation-rmse:5.49458
# [563]	validation-rmse:5.49448
# [564]	validation-rmse:5.49442
# [565]	validation-rmse:5.49425
# [566]	validation-rmse:5.49417
# [567]	validation-rmse:5.49386
# [568]	validation-rmse:5.49386
# [569]	validation-rmse:5.49386
# [570]	validation-rmse:5.49377
# [571]	validation-rmse:5.49364
# [572]	validation-rmse:5.49359
# [573]	validation-rmse:5.49340
# [574]	validation-rmse:5.49321
# [575]	validation-rmse:5.49309
# [576]	validation-rmse:5.49297
# [577]	validation-rmse:5.49268
# [578]	validation-rmse:5.49259
# [579]	validation-rmse:5.49243
# [580]	validation-rmse:5.49214
# [581]	validation-rmse:5.49210
# [582]	validation-rmse:5.49191
# [583]	validation-rmse:5.49180
# [584]	validation-rmse:5.49173
# [585]	validation-rmse:5.49172
# [586]	validation-rmse:5.49152
# [587]	validation-rmse:5.49142
# [588]	validation-rmse:5.49127
# [589]	validation-rmse:5.49098
# [590]	validation-rmse:5.49090
# [591]	validation-rmse:5.49088
# [592]	validation-rmse:5.49085
# [593]	validation-rmse:5.49078
# [594]	validation-rmse:5.49077
# [595]	validation-rmse:5.49074
# [596]	validation-rmse:5.49075
# [597]	validation-rmse:5.49068
# [598]	validation-rmse:5.49066
# [599]	validation-rmse:5.49065
# [600]	validation-rmse:5.49050
# [601]	validation-rmse:5.49031
# [602]	validation-rmse:5.49027
# [603]	validation-rmse:5.49016
# [604]	validation-rmse:5.49010
# [605]	validation-rmse:5.49009
# [606]	validation-rmse:5.49005
# [607]	validation-rmse:5.49000
# [608]	validation-rmse:5.48992
# [609]	validation-rmse:5.48991
# [610]	validation-rmse:5.48989
# [611]	validation-rmse:5.48983
# [612]	validation-rmse:5.48980
# [613]	validation-rmse:5.48955
# [614]	validation-rmse:5.48950
# [615]	validation-rmse:5.48945
# [616]	validation-rmse:5.48941
# [617]	validation-rmse:5.48939
# [618]	validation-rmse:5.48931
# [619]	validation-rmse:5.48925
# [620]	validation-rmse:5.48907
# [621]	validation-rmse:5.48882
# [622]	validation-rmse:5.48872
# [623]	validation-rmse:5.48860
# [624]	validation-rmse:5.48817
# [625]	validation-rmse:5.48805
# [626]	validation-rmse:5.48798
# [627]	validation-rmse:5.48774
# [628]	validation-rmse:5.48772
# [629]	validation-rmse:5.48771
# [630]	validation-rmse:5.48768
# [631]	validation-rmse:5.48763
# [632]	validation-rmse:5.48756
# [633]	validation-rmse:5.48748
# [634]	validation-rmse:5.48745
# [635]	validation-rmse:5.48741
# [636]	validation-rmse:5.48735
# [637]	validation-rmse:5.48733
# [638]	validation-rmse:5.48702
# [639]	validation-rmse:5.48700
# [640]	validation-rmse:5.48685
# [641]	validation-rmse:5.48677
# [642]	validation-rmse:5.48672
# [643]	validation-rmse:5.48663
# [644]	validation-rmse:5.48655
# [645]	validation-rmse:5.48654
# [646]	validation-rmse:5.48649
# [647]	validation-rmse:5.48638
# [648]	validation-rmse:5.48629
# [649]	validation-rmse:5.48595
# [650]	validation-rmse:5.48589
# [651]	validation-rmse:5.48568
# [652]	validation-rmse:5.48529
# [653]	validation-rmse:5.48495
# [654]	validation-rmse:5.48477
# [655]	validation-rmse:5.48446
# [656]	validation-rmse:5.48417
# [657]	validation-rmse:5.48401
# [658]	validation-rmse:5.48395
# [659]	validation-rmse:5.48390
# [660]	validation-rmse:5.48362
# [661]	validation-rmse:5.48302
# [662]	validation-rmse:5.48260
# [663]	validation-rmse:5.48227
# [664]	validation-rmse:5.48198
# [665]	validation-rmse:5.48189
# [666]	validation-rmse:5.48159
# [667]	validation-rmse:5.48141
# [668]	validation-rmse:5.48130
# [669]	validation-rmse:5.48121
# [670]	validation-rmse:5.48099
# [671]	validation-rmse:5.48067
# [672]	validation-rmse:5.48056
# [673]	validation-rmse:5.48049
# [674]	validation-rmse:5.48050
# [675]	validation-rmse:5.48047
# [676]	validation-rmse:5.48037
# [677]	validation-rmse:5.48026
# [678]	validation-rmse:5.48024
# [679]	validation-rmse:5.48003
# [680]	validation-rmse:5.47979
# [681]	validation-rmse:5.47968
# [682]	validation-rmse:5.47922
# [683]	validation-rmse:5.47911
# [684]	validation-rmse:5.47888
# [685]	validation-rmse:5.47874
# [686]	validation-rmse:5.47866
# [687]	validation-rmse:5.47850
# [688]	validation-rmse:5.47845
# [689]	validation-rmse:5.47843
# [690]	validation-rmse:5.47836
# [691]	validation-rmse:5.47814
# [692]	validation-rmse:5.47806
# [693]	validation-rmse:5.47806
# [694]	validation-rmse:5.47798
# [695]	validation-rmse:5.47789
# [696]	validation-rmse:5.47785
# [697]	validation-rmse:5.47784
# [698]	validation-rmse:5.47755
# [699]	validation-rmse:5.47744
# [700]	validation-rmse:5.47740
# [701]	validation-rmse:5.47739
# [702]	validation-rmse:5.47737
# [703]	validation-rmse:5.47736
# [704]	validation-rmse:5.47735
# [705]	validation-rmse:5.47699
# [706]	validation-rmse:5.47692
# [707]	validation-rmse:5.47680
# [708]	validation-rmse:5.47668
# [709]	validation-rmse:5.47656
# [710]	validation-rmse:5.47651
# [711]	validation-rmse:5.47650
# [712]	validation-rmse:5.47643
# [713]	validation-rmse:5.47642
# [714]	validation-rmse:5.47630
# [715]	validation-rmse:5.47610
# [716]	validation-rmse:5.47608
# [717]	validation-rmse:5.47603
# [718]	validation-rmse:5.47601
# [719]	validation-rmse:5.47583
# [720]	validation-rmse:5.47573
# [721]	validation-rmse:5.47566
# [722]	validation-rmse:5.47556
# [723]	validation-rmse:5.47554
# [724]	validation-rmse:5.47554
# [725]	validation-rmse:5.47551
# [726]	validation-rmse:5.47545
# [727]	validation-rmse:5.47535
# [728]	validation-rmse:5.47535
# [729]	validation-rmse:5.47534
# [730]	validation-rmse:5.47532
# [731]	validation-rmse:5.47532
# [732]	validation-rmse:5.47531
# [733]	validation-rmse:5.47530
# [734]	validation-rmse:5.47529
# [735]	validation-rmse:5.47526
# [736]	validation-rmse:5.47522
# [737]	validation-rmse:5.47521
# [738]	validation-rmse:5.47521
# [739]	validation-rmse:5.47520
# [740]	validation-rmse:5.47520
# [741]	validation-rmse:5.47520
# [742]	validation-rmse:5.47520
# [743]	validation-rmse:5.47520
# [744]	validation-rmse:5.47515
# [745]	validation-rmse:5.47514
# [746]	validation-rmse:5.47513
# [747]	validation-rmse:5.47512
# [748]	validation-rmse:5.47510
# [749]	validation-rmse:5.47509
# [750]	validation-rmse:5.47508
# [751]	validation-rmse:5.47507
# [752]	validation-rmse:5.47508
# [753]	validation-rmse:5.47507
# [754]	validation-rmse:5.47506
# [755]	validation-rmse:5.47506
# [756]	validation-rmse:5.47502
# [757]	validation-rmse:5.47499
# [758]	validation-rmse:5.47499
# [759]	validation-rmse:5.47499
# [760]	validation-rmse:5.47499
# [761]	validation-rmse:5.47498
# [762]	validation-rmse:5.47498
# [763]	validation-rmse:5.47498
# [764]	validation-rmse:5.47497
# [765]	validation-rmse:5.47496
# [766]	validation-rmse:5.47496
# [767]	validation-rmse:5.47495
# [768]	validation-rmse:5.47494
# [769]	validation-rmse:5.47495
# [770]	validation-rmse:5.47494
# [771]	validation-rmse:5.47493
# [772]	validation-rmse:5.47493
# [773]	validation-rmse:5.47492
# [774]	validation-rmse:5.47491
# [775]	validation-rmse:5.47491
# [776]	validation-rmse:5.47490
# [777]	validation-rmse:5.47489
# [778]	validation-rmse:5.47489
# [779]	validation-rmse:5.47489
# [780]	validation-rmse:5.47488
# [781]	validation-rmse:5.47488
# [782]	validation-rmse:5.47487
# [783]	validation-rmse:5.47487
# [784]	validation-rmse:5.47487
# [785]	validation-rmse:5.47486
# [786]	validation-rmse:5.47486
# [787]	validation-rmse:5.47485
# [788]	validation-rmse:5.47484
# [789]	validation-rmse:5.47484
# [790]	validation-rmse:5.47483
# [791]	validation-rmse:5.47483
# [792]	validation-rmse:5.47483
# [793]	validation-rmse:5.47483
# [794]	validation-rmse:5.47482
# [795]	validation-rmse:5.47482
# [796]	validation-rmse:5.47482
# [797]	validation-rmse:5.47481
# [798]	validation-rmse:5.47481
# [799]	validation-rmse:5.47480
# [800]	validation-rmse:5.47480
# [801]	validation-rmse:5.47480
# [802]	validation-rmse:5.47479
# [803]	validation-rmse:5.47476
# [804]	validation-rmse:5.47476
# [805]	validation-rmse:5.47477
# [806]	validation-rmse:5.47476
# [807]	validation-rmse:5.47476
# [808]	validation-rmse:5.47476
# [809]	validation-rmse:5.47475
# [810]	validation-rmse:5.47475
# [811]	validation-rmse:5.47475
# [812]	validation-rmse:5.47475
# [813]	validation-rmse:5.47474
# [814]	validation-rmse:5.47474
# [815]	validation-rmse:5.47473
# [816]	validation-rmse:5.47473
# [817]	validation-rmse:5.47474
# [818]	validation-rmse:5.47473
# [819]	validation-rmse:5.47473
# [820]	validation-rmse:5.47472
# [821]	validation-rmse:5.47472
# [822]	validation-rmse:5.47472
# [823]	validation-rmse:5.47471
# [824]	validation-rmse:5.47471
# [825]	validation-rmse:5.47471
# [826]	validation-rmse:5.47471
# [827]	validation-rmse:5.47470
# [828]	validation-rmse:5.47469
# [829]	validation-rmse:5.47469
# [830]	validation-rmse:5.47468
# [831]	validation-rmse:5.47467
# [832]	validation-rmse:5.47466
# [833]	validation-rmse:5.47466
# [834]	validation-rmse:5.47465
# [835]	validation-rmse:5.47465
# [836]	validation-rmse:5.47465
# [837]	validation-rmse:5.47465
# [838]	validation-rmse:5.47465
# [839]	validation-rmse:5.47465
# [840]	validation-rmse:5.47465
# [841]	validation-rmse:5.47465
# [842]	validation-rmse:5.47463
# [843]	validation-rmse:5.47463
# [844]	validation-rmse:5.47462
# [845]	validation-rmse:5.47461
# [846]	validation-rmse:5.47461
# [847]	validation-rmse:5.47457
# [848]	validation-rmse:5.47457
# [849]	validation-rmse:5.47457
# [850]	validation-rmse:5.47457
# [851]	validation-rmse:5.47456
# [852]	validation-rmse:5.47455
# [853]	validation-rmse:5.47456
# [854]	validation-rmse:5.47455
# [855]	validation-rmse:5.47454
# [856]	validation-rmse:5.47455
# [857]	validation-rmse:5.47454
# [858]	validation-rmse:5.47453
# [859]	validation-rmse:5.47453
# [860]	validation-rmse:5.47454
# [861]	validation-rmse:5.47455
# [862]	validation-rmse:5.47454
# [863]	validation-rmse:5.47453
# [864]	validation-rmse:5.47453
# [865]	validation-rmse:5.47452
# [866]	validation-rmse:5.47453
# [867]	validation-rmse:5.47453
# [868]	validation-rmse:5.47452
# [869]	validation-rmse:5.47453
# [870]	validation-rmse:5.47453
# [871]	validation-rmse:5.47453
# [872]	validation-rmse:5.47453
# [873]	validation-rmse:5.47452
# [874]	validation-rmse:5.47452
# [875]	validation-rmse:5.47452
# [876]	validation-rmse:5.47451
# [877]	validation-rmse:5.47450
# [878]	validation-rmse:5.47450
# [879]	validation-rmse:5.47451
# [880]	validation-rmse:5.47450
# [881]	validation-rmse:5.47450
# [882]	validation-rmse:5.47450
# [883]	validation-rmse:5.47450
# [884]	validation-rmse:5.47449
# [885]	validation-rmse:5.47449
# [886]	validation-rmse:5.47450
# [887]	validation-rmse:5.47450
# [888]	validation-rmse:5.47450
# [889]	validation-rmse:5.47450
# [890]	validation-rmse:5.47450
# [891]	validation-rmse:5.47450
# [892]	validation-rmse:5.47450
# [893]	validation-rmse:5.47450
# [894]	validation-rmse:5.47450
# [895]	validation-rmse:5.47450
# [896]	validation-rmse:5.47449
# [897]	validation-rmse:5.47449
# [898]	validation-rmse:5.47449
# [899]	validation-rmse:5.47449
# [900]	validation-rmse:5.47449
# [901]	validation-rmse:5.47449
# [902]	validation-rmse:5.47448
# [903]	validation-rmse:5.47449
# [904]	validation-rmse:5.47445
# [905]	validation-rmse:5.47445
# [906]	validation-rmse:5.47444
# [907]	validation-rmse:5.47446
# [908]	validation-rmse:5.47445
# [909]	validation-rmse:5.47446
# [910]	validation-rmse:5.47444
# [911]	validation-rmse:5.47441
# [912]	validation-rmse:5.47440
# [913]	validation-rmse:5.47441
# [914]	validation-rmse:5.47440
# [915]	validation-rmse:5.47441
# [916]	validation-rmse:5.47439
# [917]	validation-rmse:5.47438
# [918]	validation-rmse:5.47437
# [919]	validation-rmse:5.47439
# [920]	validation-rmse:5.47439
# [921]	validation-rmse:5.47434
# [922]	validation-rmse:5.47433
# [923]	validation-rmse:5.47434
# [924]	validation-rmse:5.47433
# [925]	validation-rmse:5.47433
# [926]	validation-rmse:5.47433
# [927]	validation-rmse:5.47433
# [928]	validation-rmse:5.47433
# [929]	validation-rmse:5.47433
# [930]	validation-rmse:5.47432
# [931]	validation-rmse:5.47432
# [932]	validation-rmse:5.47432
# [933]	validation-rmse:5.47431
# [934]	validation-rmse:5.47431
# [935]	validation-rmse:5.47430
# [936]	validation-rmse:5.47431
# [937]	validation-rmse:5.47430
# [938]	validation-rmse:5.47431
# [939]	validation-rmse:5.47430
# [940]	validation-rmse:5.47428
# [941]	validation-rmse:5.47427
# [942]	validation-rmse:5.47426
# [943]	validation-rmse:5.47425
# [944]	validation-rmse:5.47425
# [945]	validation-rmse:5.47425
# [946]	validation-rmse:5.47425
# [947]	validation-rmse:5.47424
# [948]	validation-rmse:5.47424
# [949]	validation-rmse:5.47424
# [950]	validation-rmse:5.47425
# [951]	validation-rmse:5.47424
# [952]	validation-rmse:5.47424
# [953]	validation-rmse:5.47423
# [954]	validation-rmse:5.47423
# [955]	validation-rmse:5.47422
# [956]	validation-rmse:5.47422
# [957]	validation-rmse:5.47422
# [958]	validation-rmse:5.47422
# [959]	validation-rmse:5.47421
# [960]	validation-rmse:5.47420
# [961]	validation-rmse:5.47420
# [962]	validation-rmse:5.47420
# [963]	validation-rmse:5.47420
# [964]	validation-rmse:5.47419
# [965]	validation-rmse:5.47418
# [966]	validation-rmse:5.47418
# [967]	validation-rmse:5.47418
# [968]	validation-rmse:5.47417
# [969]	validation-rmse:5.47417
# [970]	validation-rmse:5.47417
# [971]	validation-rmse:5.47416
# [972]	validation-rmse:5.47416
# [973]	validation-rmse:5.47416
# [974]	validation-rmse:5.47415
# [975]	validation-rmse:5.47415
# [976]	validation-rmse:5.47415
# [977]	validation-rmse:5.47415
# [978]	validation-rmse:5.47413
# [979]	validation-rmse:5.47412
# [980]	validation-rmse:5.47411
# [981]	validation-rmse:5.47411
# [982]	validation-rmse:5.47411
# [983]	validation-rmse:5.47411
# [984]	validation-rmse:5.47411
# [985]	validation-rmse:5.47411
# [986]	validation-rmse:5.47411
# [987]	validation-rmse:5.47410
# [988]	validation-rmse:5.47409
# [989]	validation-rmse:5.47409
# [990]	validation-rmse:5.47409
# [991]	validation-rmse:5.47409
# [992]	validation-rmse:5.47408
# [993]	validation-rmse:5.47408
# [994]	validation-rmse:5.47409
# [995]	validation-rmse:5.47409
# [996]	validation-rmse:5.47409
# [997]	validation-rmse:5.47409
# [998]	validation-rmse:5.47408
# [999]	validation-rmse:5.47408
# 2023/05/21 15:25:56 WARNING mlflow.xgboost: Failed to infer model signature: could not sample data to infer model signature: please ensure that autologging is enabled before constructing the dataset.
# 2023/05/21 15:25:59 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/dan/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils."
